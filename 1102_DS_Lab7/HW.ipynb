# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns; sns.set()

# %%
x = np.array([59, 52, 44, 51, 42, 42, 41, 45, 27, 63, 54, 44, 50, 47])
y = np.array([56, 63, 55, 50, 66, 48, 58, 36, 13, 50, 81, 56 ,64, 50])

# %%
plt.scatter(x, y);

# %%
x[:,np.newaxis].shape
# Out:
# (14, 1)

# %% [markdown]
# from sklearn.datasets import make_regression
# XX, yy = make_regression(n_samples=1000, n_features=3)
# XX.shape
# yy.shape

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression(fit_intercept=True) # 一般採用預設參數設置，可根據自己實際要求設置參數
model.fit(x[:, np.newaxis], y) # 訓練

xfit = np.linspace(20, 70, 1000)  # 繪圖用的x軸座標
y_pred = model.predict(xfit[:, np.newaxis])  # 使用 x軸座標值 預測 y 值

plt.scatter(x, y)
plt.plot(xfit, y_pred, 'r');    # 用紅線標示
